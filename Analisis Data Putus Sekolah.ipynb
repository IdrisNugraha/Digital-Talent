# %% [markdown]
# # Data Putus Sekolah SD, SMP, SMA & SMK

# %% [markdown]
# # Projects
# Temukan data yang menurut kalian menarik pada http://data.go.id . Buat analisa data yang berisi:
#
# 1. Deskripsi Data
# 2. Statistik tentang data
# 3. Visualisasi sederhana
# 4. Narasi analisis
#
# Buat dalam sebuah Notebook dengan judul Analisa Data X, dimana X adalah Deskripsi Data yang dianalisa. Submit link menuju notebooknya di elisa.

# %% [markdown]
# # 1. DESKRIPSI DATA

# %%
import pandas as pd
import numpy as np
import os
import statistics as stat
import math

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Videos\\Artificial\\Tugas3'

# %%
os.chdir('\\Users\\user\\Videos\\Artificial\\Tugas3')

# %%
dataPutusSd=pd.read_csv('processed-data-putus-sekolah-sd-2008-2011.csv')
dataPutusSmP=pd.read_csv('processed-data-putus-sekolah-smp-2008-2011.csv')
dataPutusSmA=pd.read_csv('processed-data-putus-sekolah-sma-2008-2011.csv')
dataPutusSmK=pd.read_csv('processed-data-putus-sekolah-smk-2008-2011.csv')

# %% [markdown]
# # Data Putus Sekolah Dasar

# %%
dataPutusSd
# Out:
#      kode_provinsi                   nama_provinsi  tahun  \
# 0               11  Prov. Nanggroe Aceh Darussalam   2008
# 1               11  Prov. Nanggroe Aceh Darussalam   2009
# 2               11  Prov. Nanggroe Aceh Darussalam   2010
# 3               11  Prov. Nanggroe Aceh Darussalam   2011
# 4               12            Prov. Sumatera Utara   2008
# 5               12            Prov. Sumatera Utara   2009
# 6               12            Prov. Sumatera Utara   2010
# 7               12            Prov. Sumatera Utara   2011
# 8               13            Prov. Sumatera Barat   2008
# 9               13            Prov. Sumatera Barat   2009
# 10              13            Prov. Sumatera Barat   2010
# 11              13            Prov. Sumatera Barat   2011
# 12              14                      Prov. Riau   2008
# 13              14                      Prov. Riau   2009
# 14              14                      Prov. Riau   2010
# ...

# %% [markdown]
# # Data Putus Sekolah Menengah Pertama

# %%
dataPutusSmP
# Out:
#      kode_provinsi                   nama_provinsi  tahun  \
# 0               11  Prov. Nanggroe Aceh Darussalam   2008
# 1               11  Prov. Nanggroe Aceh Darussalam   2009
# 2               11  Prov. Nanggroe Aceh Darussalam   2010
# 3               11  Prov. Nanggroe Aceh Darussalam   2011
# 4               12            Prov. Sumatera Utara   2008
# 5               12            Prov. Sumatera Utara   2009
# 6               12            Prov. Sumatera Utara   2010
# 7               12            Prov. Sumatera Utara   2011
# 8               13            Prov. Sumatera Barat   2008
# 9               13            Prov. Sumatera Barat   2009
# 10              13            Prov. Sumatera Barat   2010
# 11              13            Prov. Sumatera Barat   2011
# 12              14                      Prov. Riau   2008
# 13              14                      Prov. Riau   2009
# 14              14                      Prov. Riau   2010
# ...

# %% [markdown]
# # Data Putus Sekolah Menengah Atas

# %%
dataPutusSmA
# Out:
#      kode_provinsi                   nama_provinsi  tahun  \
# 0               11  Prov. Nanggroe Aceh Darussalam   2008
# 1               11  Prov. Nanggroe Aceh Darussalam   2009
# 2               11  Prov. Nanggroe Aceh Darussalam   2010
# 3               11  Prov. Nanggroe Aceh Darussalam   2011
# 4               12            Prov. Sumatera Utara   2008
# 5               12            Prov. Sumatera Utara   2009
# 6               12            Prov. Sumatera Utara   2010
# 7               12            Prov. Sumatera Utara   2011
# 8               13            Prov. Sumatera Barat   2008
# 9               13            Prov. Sumatera Barat   2009
# 10              13            Prov. Sumatera Barat   2010
# 11              13            Prov. Sumatera Barat   2011
# 12              14                      Prov. Riau   2008
# 13              14                      Prov. Riau   2009
# 14              14                      Prov. Riau   2010
# ...

# %% [markdown]
# # Data Putus Sekolah Menengah Kejuruan

# %%
dataPutusSmK
# Out:
#      kode_provinsi                   nama_provinsi  tahun  \
# 0               11  Prov. Nanggroe Aceh Darussalam   2008
# 1               11  Prov. Nanggroe Aceh Darussalam   2009
# 2               11  Prov. Nanggroe Aceh Darussalam   2010
# 3               11  Prov. Nanggroe Aceh Darussalam   2011
# 4               12            Prov. Sumatera Utara   2008
# 5               12            Prov. Sumatera Utara   2009
# 6               12            Prov. Sumatera Utara   2010
# 7               12            Prov. Sumatera Utara   2011
# 8               13            Prov. Sumatera Barat   2008
# 9               13            Prov. Sumatera Barat   2009
# 10              13            Prov. Sumatera Barat   2010
# 11              13            Prov. Sumatera Barat   2011
# 12              14                      Prov. Riau   2008
# 13              14                      Prov. Riau   2009
# 14              14                      Prov. Riau   2010
# ...

# %% [markdown]
# # Melihat Data

# %% [markdown]
# # Data Putus Sekolah Dasar

# %%
dataPutusSd.columns
# Out:
# Index(['kode_provinsi', 'nama_provinsi', 'tahun', 'jumlah_putus_sekolah',
#        'persen_putus_sekolah'],
#       dtype='object')

# %%
dataPutusSd.head()
# Out:
#    kode_provinsi                   nama_provinsi  tahun  jumlah_putus_sekolah  \
# 0             11  Prov. Nanggroe Aceh Darussalam   2008                 12098
# 1             11  Prov. Nanggroe Aceh Darussalam   2009                 11944
# 2             11  Prov. Nanggroe Aceh Darussalam   2010                 11569
# 3             11  Prov. Nanggroe Aceh Darussalam   2011                  4389
# 4             12            Prov. Sumatera Utara   2008                 20868
#
#    persen_putus_sekolah
# 0              2.188602
# 1              2.167435
# 2              2.119237
# 3              0.801634
# 4              1.140954

# %%
dataPutusSd.tail()
# Out:
#      kode_provinsi      nama_provinsi  tahun  jumlah_putus_sekolah  \
# 127             91  Prov. Papua Barat   2011                  2089
# 128             94        Prov. Papua   2008                  8783
# 129             94        Prov. Papua   2009                  8544
# 130             94        Prov. Papua   2010                  8100
# 131             94        Prov. Papua   2011                  4619
#
#      persen_putus_sekolah
# 127              1.722333
# 128              3.099777
# 129              2.813062
# 130              2.486447
# 131              1.431112

# %%
dataPutusSd.sample(5)
# Out:
#     kode_provinsi              nama_provinsi  tahun  jumlah_putus_sekolah  \
# 71             52  Prov. Nusa Tenggara Barat   2011                  4669
# 43             31          Prov. DKI Jakarta   2011                  6160
# 76             61     Prov. Kalimantan Barat   2008                 16142
# 72             53  Prov. Nusa Tenggara Timur   2008                 26009
# 22             16     Prov. Sumatera Selatan   2010                 15750
#
#     persen_putus_sekolah
# 71              0.819953
# 43              0.735935
# 76              2.536224
# 72              3.488341
# 22              1.635884

# %%
dataPutusSd[['nama_provinsi', 'tahun', 'jumlah_putus_sekolah']]
# Out:
#                       nama_provinsi  tahun  jumlah_putus_sekolah
# 0    Prov. Nanggroe Aceh Darussalam   2008                 12098
# 1    Prov. Nanggroe Aceh Darussalam   2009                 11944
# 2    Prov. Nanggroe Aceh Darussalam   2010                 11569
# 3    Prov. Nanggroe Aceh Darussalam   2011                  4389
# 4              Prov. Sumatera Utara   2008                 20868
# 5              Prov. Sumatera Utara   2009                 26594
# 6              Prov. Sumatera Utara   2010                 26237
# 7              Prov. Sumatera Utara   2011                 15415
# 8              Prov. Sumatera Barat   2008                 16371
# 9              Prov. Sumatera Barat   2009                 16992
# 10             Prov. Sumatera Barat   2010                 15522
# 11             Prov. Sumatera Barat   2011                  6175
# 12                       Prov. Riau   2008                 17767
# ...

# %% [markdown]
# # Data Putus Sekolah Menengah Pertama

# %%
dataPutusSmP.columns
# Out:
# Index(['kode_provinsi', 'nama_provinsi', 'tahun', 'jumlah_putus_sekolah',
#        'persen_putus_sekolah'],
#       dtype='object')

# %%
dataPutusSmP.head()
# Out:
#    kode_provinsi                   nama_provinsi  tahun  jumlah_putus_sekolah  \
# 0             11  Prov. Nanggroe Aceh Darussalam   2008                  8563
# 1             11  Prov. Nanggroe Aceh Darussalam   2009                   746
# 2             11  Prov. Nanggroe Aceh Darussalam   2010                  7236
# 3             11  Prov. Nanggroe Aceh Darussalam   2011                  2699
# 4             12            Prov. Sumatera Utara   2008                 15925
#
#    persen_putus_sekolah
# 0              3.932997
# 1              0.348821
# 2              3.377946
# 3              1.332188
# 4              2.476753

# %%
dataPutusSmP.tail()
# Out:
#      kode_provinsi      nama_provinsi  tahun  jumlah_putus_sekolah  \
# 127             91  Prov. Papua Barat   2011                  1050
# 128             94        Prov. Papua   2008                  3880
# 129             94        Prov. Papua   2009                  2617
# 130             94        Prov. Papua   2010                  3122
# 131             94        Prov. Papua   2011                  2410
#
#      persen_putus_sekolah
# 127              2.820988
# 128              4.233635
# 129              2.734759
# 130              3.169865
# 131              2.376023

# %%
dataPutusSmP.sample(5)
# Out:
#     kode_provinsi              nama_provinsi  tahun  jumlah_putus_sekolah  \
# 58             35           Prov. Jawa Timur   2010                 13218
# 69             52  Prov. Nusa Tenggara Barat   2009                  3730
# 14             14                 Prov. Riau   2010                  5611
# 17             15                Prov. Jambi   2009                  1010
# 54             34       Prov. D I Yogyakarta   2010                   300
#
#     persen_putus_sekolah
# 58              1.084416
# 69              2.268180
# 14              2.858919
# 17              0.913597
# 54              0.224373

# %%
dataPutusSmP[['nama_provinsi', 'tahun', 'jumlah_putus_sekolah']]
# Out:
#                       nama_provinsi  tahun  jumlah_putus_sekolah
# 0    Prov. Nanggroe Aceh Darussalam   2008                  8563
# 1    Prov. Nanggroe Aceh Darussalam   2009                   746
# 2    Prov. Nanggroe Aceh Darussalam   2010                  7236
# 3    Prov. Nanggroe Aceh Darussalam   2011                  2699
# 4              Prov. Sumatera Utara   2008                 15925
# 5              Prov. Sumatera Utara   2009                   152
# 6              Prov. Sumatera Utara   2010                 12608
# 7              Prov. Sumatera Utara   2011                  4925
# 8              Prov. Sumatera Barat   2008                  3767
# 9              Prov. Sumatera Barat   2009                    75
# 10             Prov. Sumatera Barat   2010                  2355
# 11             Prov. Sumatera Barat   2011                  3093
# 12                       Prov. Riau   2008                  5903
# ...

# %% [markdown]
# # Data Putus Sekolah Menengah Atas

# %%
dataPutusSmA.columns
# Out:
# Index(['kode_provinsi', 'nama_provinsi', 'tahun', 'jumlah_putus_sekolah',
#        'persen_putus_sekolah'],
#       dtype='object')

# %%
dataPutusSmA.head()
# Out:
#    kode_provinsi                   nama_provinsi  tahun  jumlah_putus_sekolah  \
# 0             11  Prov. Nanggroe Aceh Darussalam   2008                   456
# 1             11  Prov. Nanggroe Aceh Darussalam   2009                  5206
# 2             11  Prov. Nanggroe Aceh Darussalam   2010                  4974
# 3             11  Prov. Nanggroe Aceh Darussalam   2011                  1279
# 4             12            Prov. Sumatera Utara   2008                 22812
#
#    persen_putus_sekolah
# 0              0.373985
# 1              3.787008
# 2              3.458297
# 3              0.859601
# 4              6.897386

# %%
dataPutusSmA.tail()
# Out:
#      kode_provinsi      nama_provinsi  tahun  jumlah_putus_sekolah  \
# 127             91  Prov. Papua Barat   2011                   320
# 128             94        Prov. Papua   2008                  2092
# 129             94        Prov. Papua   2009                  2275
# 130             94        Prov. Papua   2010                  2015
# 131             94        Prov. Papua   2011                   981
#
#      persen_putus_sekolah
# 127              1.677588
# 128              5.444939
# 129              5.664135
# 130              4.889115
# 131              2.301250

# %%
dataPutusSmA.sample(5)
# Out:
#     kode_provinsi           nama_provinsi  tahun  jumlah_putus_sekolah  \
# 96             72   Prov. Sulawesi Tengah   2008                   437
# 60             36            Prov. Banten   2008                  2032
# 20             16  Prov. Sumatera Selatan   2008                  7646
# 29             18           Prov. Lampung   2009                  1960
# 21             16  Prov. Sumatera Selatan   2009                  9386
#
#     persen_putus_sekolah
# 96              0.998538
# 60              1.591267
# 20              4.635175
# 29              1.770135
# 21              5.432153

# %%
dataPutusSd[['nama_provinsi', 'tahun', 'jumlah_putus_sekolah']]
# Out:
#                       nama_provinsi  tahun  jumlah_putus_sekolah
# 0    Prov. Nanggroe Aceh Darussalam   2008                 12098
# 1    Prov. Nanggroe Aceh Darussalam   2009                 11944
# 2    Prov. Nanggroe Aceh Darussalam   2010                 11569
# 3    Prov. Nanggroe Aceh Darussalam   2011                  4389
# 4              Prov. Sumatera Utara   2008                 20868
# 5              Prov. Sumatera Utara   2009                 26594
# 6              Prov. Sumatera Utara   2010                 26237
# 7              Prov. Sumatera Utara   2011                 15415
# 8              Prov. Sumatera Barat   2008                 16371
# 9              Prov. Sumatera Barat   2009                 16992
# 10             Prov. Sumatera Barat   2010                 15522
# 11             Prov. Sumatera Barat   2011                  6175
# 12                       Prov. Riau   2008                 17767
# ...

# %% [markdown]
# # Data Putus Sekolah Menengah Kejuruan

# %%
dataPutusSmK.columns
# Out:
# Index(['kode_provinsi', 'nama_provinsi', 'tahun', 'jumlah_putus_sekolah',
#        'persen_putus_sekolah'],
#       dtype='object')

# %%
dataPutusSmK.head()
# Out:
#    kode_provinsi                   nama_provinsi  tahun  jumlah_putus_sekolah  \
# 0             11  Prov. Nanggroe Aceh Darussalam   2008                  2299
# 1             11  Prov. Nanggroe Aceh Darussalam   2009                  2004
# 2             11  Prov. Nanggroe Aceh Darussalam   2010                  2512
# 3             11  Prov. Nanggroe Aceh Darussalam   2011                  3814
# 4             12            Prov. Sumatera Utara   2008                  5150
#
#    persen_putus_sekolah
# 0              1.752778
# 1              7.680208
# 2              5.799243
# 3              8.067177
# 4              1.342826

# %%
dataPutusSmK.tail()
# Out:
#      kode_provinsi      nama_provinsi  tahun  jumlah_putus_sekolah  \
# 127             91  Prov. Papua Barat   2011                  2410
# 128             94        Prov. Papua   2008                   746
# 129             94        Prov. Papua   2009                   888
# 130             94        Prov. Papua   2010                  1507
# 131             94        Prov. Papua   2011                  3365
#
#      persen_putus_sekolah
# 127             15.301590
# 128              2.200651
# 129              3.880080
# 130              5.936343
# 131             12.038930

# %%
dataPutusSmK.sample(5)
# Out:
#      kode_provinsi           nama_provinsi  tahun  jumlah_putus_sekolah  \
# 116             81            Prov. Maluku   2008                   278
# 25              17          Prov. Bengkulu   2009                   923
# 29              18           Prov. Lampung   2009                  4750
# 88              64  Prov. Kalimantan Timur   2008                  2502
# 28              18           Prov. Lampung   2008                  1418
#
#      persen_putus_sekolah
# 116              2.181547
# 25               2.031491
# 29               1.845307
# 88               1.983055
# 28               1.091472

# %%
dataPutusSmK[['nama_provinsi', 'tahun', 'jumlah_putus_sekolah']]
# Out:
#                       nama_provinsi  tahun  jumlah_putus_sekolah
# 0    Prov. Nanggroe Aceh Darussalam   2008                  2299
# 1    Prov. Nanggroe Aceh Darussalam   2009                  2004
# 2    Prov. Nanggroe Aceh Darussalam   2010                  2512
# 3    Prov. Nanggroe Aceh Darussalam   2011                  3814
# 4              Prov. Sumatera Utara   2008                  5150
# 5              Prov. Sumatera Utara   2009                 12679
# 6              Prov. Sumatera Utara   2010                  6157
# 7              Prov. Sumatera Utara   2011                  6945
# 8              Prov. Sumatera Barat   2008                  2781
# 9              Prov. Sumatera Barat   2009                  3635
# 10             Prov. Sumatera Barat   2010                  5219
# 11             Prov. Sumatera Barat   2011                  4602
# 12                       Prov. Riau   2008                  1590
# ...

# %% [markdown]
# # 2. STATISTIK TENTANG DATA

# %% [markdown]
# # Data Putus Sekolah Dasar

# %%
dataPutusSd.kode_provinsi.count()
# Out:
# 132

# %%
s=dataPutusSd.jumlah_putus_sekolah.sum()
mi=dataPutusSd.jumlah_putus_sekolah.min()
ma=dataPutusSd.jumlah_putus_sekolah.max()

print(s,mi,ma)
# Out:
# 1570704 786 66876

# %%
me=dataPutusSd.jumlah_putus_sekolah.mean()
md=dataPutusSd.jumlah_putus_sekolah.median()

print(me, md)
# Out:
# 11899.272727272728 7845.5

# %% [markdown]
# # Data Putus Sekolah Menengah Pertama

# %%
dataPutusSmP.kode_provinsi.count()
# Out:
# 132

# %%
s=dataPutusSmP.jumlah_putus_sekolah.sum()
mi=dataPutusSmP.jumlah_putus_sekolah.min()
ma=dataPutusSmP.jumlah_putus_sekolah.max()

print(s,mi,ma)
# Out:
# 713305 13 75416

# %%
me=dataPutusSmP.jumlah_putus_sekolah.mean()
md=dataPutusSmP.jumlah_putus_sekolah.median()

print(me, md)
# Out:
# 5403.825757575758 2680.5

# %% [markdown]
# # Data Putus Sekolah Menengah Atas

# %%
dataPutusSmA.kode_provinsi.count()
# Out:
# 132

# %%
s=dataPutusSmA.jumlah_putus_sekolah.sum()
mi=dataPutusSmA.jumlah_putus_sekolah.min()
ma=dataPutusSmA.jumlah_putus_sekolah.max()

print(s,mi,ma)
# Out:
# 457765 128 22812

# %%
me=dataPutusSmA.jumlah_putus_sekolah.mean()
md=dataPutusSmA.jumlah_putus_sekolah.median()

print(me, md)
# Out:
# 3467.9166666666665 1923.0

# %% [markdown]
# # Data Putus Sekolah Menengah Kejuruan

# %%
dataPutusSmA.kode_provinsi.count()
# Out:
# 132

# %%
s=dataPutusSmK.jumlah_putus_sekolah.sum()
mi=dataPutusSmK.jumlah_putus_sekolah.min()
ma=dataPutusSmK.jumlah_putus_sekolah.max()

print(s,mi,ma)
# Out:
# 488296 232 28223

# %%
me=dataPutusSmK.jumlah_putus_sekolah.mean()
md=dataPutusSmK.jumlah_putus_sekolah.median()

print(me, md)
# Out:
# 3699.212121212121 2164.5

# %% [markdown]
# # VISUALISASI SEDERHANA

# %% [markdown]
# # Data Putus Sekolah Dasar

# %%
ax=dataPutusSd.groupby('tahun').mean()['jumlah_putus_sekolah']
ax= ax.plot(kind='bar', title ="Rata-Rata Berdasarkan Tahun", legend=True, fontsize=12)
ax.set_xlabel("tahun", fontsize=12)
ax.set_ylabel("jumlah_putus_sekolah", fontsize=12)
# Out:
# Text(0,0.5,'jumlah_putus_sekolah')

# %% [markdown]
# # Data Putus Sekolah Menengah Pertama

# %%
ax=dataPutusSmP.groupby('tahun').mean()['jumlah_putus_sekolah']
ax= ax.plot(kind='bar', title ="Rata-Rata Berdasarkan Tahun", legend=True, fontsize=12)
ax.set_xlabel("tahun", fontsize=12)
ax.set_ylabel("jumlah_putus_sekolah", fontsize=12)
# Out:
# Text(0,0.5,'jumlah_putus_sekolah')

# %% [markdown]
# # Data Putus Sekolah Menengah Atas

# %%
ax=dataPutusSmA.groupby('tahun').mean()['jumlah_putus_sekolah']
ax= ax.plot(kind='bar', title ="Rata-Rata Berdasarkan Tahun", legend=True, fontsize=12)
ax.set_xlabel("tahun", fontsize=12)
ax.set_ylabel("jumlah_putus_sekolah", fontsize=12)
# Out:
# Text(0,0.5,'jumlah_putus_sekolah')

# %% [markdown]
# # Data Putus Sekolah Menengah Kejuruan

# %%
ax=dataPutusSmK.groupby('tahun').mean()['jumlah_putus_sekolah']
ax= ax.plot(kind='bar', title ="Rata-Rata Berdasarkan Tahun", legend=True, fontsize=12)
ax.set_xlabel("tahun", fontsize=12)
ax.set_ylabel("jumlah_putus_sekolah", fontsize=12)
# Out:
# Text(0,0.5,'jumlah_putus_sekolah')

# %% [markdown]
# # NARASI ANALISIS

# %%
analisis="Berdasarkan data diatas terlihat bahwa tingkat putus sekolah terbanyak ditempati oleh sekolah tingkat dasar. Dimana rata-rata jumlah putus sekolah yaitu 11.899,27. Nilai ini sangat jauh jika di bandingkan jumlah putus sekolah SMP, SMA, dan SMK. Tetapi pada 2011 jumlah putus sekolah tingkat dasar mengalami penurunan secara drastis hal ini juga terjadi pada tingkat SMA. Sedangkan penurunan juga terjadi di tingkat SMP dimana dari visualisasi terlihat penurunan secara konsisten dari tahun 2008 sampai 2011. Dan untuk tingkat SMK jumlah putus sekolah tertinggi terjadi pada tahun 2009 dan turun pada tahun selanutnya secara drastis yaitu tahun 2010, tetapi peningkatan jumlah putus sekolah terjadi pada tahun 2011. Sekolah merupakan jembatan untuk memerangi kemiskinan. Pemerataan pendidikan dari Sabang hingga Merauke haruslah dilaksanakan serta diawasi sehingga jumlah putus sekolah setiap tahunnya dapat menurun dan Indonesia dapat mencetak generasi penerus bangsa yang berilmu pengetahuan sehingga dapat bersaing dengan negara lain."
print(analisis)
# Out:
# Berdasarkan data diatas terlihat bahwa tingkat putus sekolah terbanyak ditempati oleh sekolah tingkat dasar. Dimana rata-rata jumlah putus sekolah yaitu 11.899,27. Nilai ini sangat jauh jika di bandingkan jumlah putus sekolah SMP, SMA, dan SMK. Tetapi pada 2011 jumlah putus sekolah tingkat dasar mengalami penurunan secara drastis hal ini juga terjadi pada tingkat SMA. Sedangkan penurunan juga terjadi di tingkat SMP dimana dari visualisasi terlihat penurunan secara konsisten dari tahun 2008 sampai 2011. Dan untuk tingkat SMK jumlah putus sekolah tertinggi terjadi pada tahun 2009 dan turun pada tahun selanutnya secara drastis yaitu tahun 2010, tetapi peningkatan jumlah putus sekolah terjadi pada tahun 2011. Sekolah merupakan jembatan untuk memerangi kemiskinan. Pemerataan pendidikan dari Sabang hingga Merauke haruslah dilaksanakan serta diawasi sehingga jumlah putus sekolah setiap tahunnya dapat menurun dan Indonesia dapat mencetak generasi penerus bangsa yang berilmu pengetahuan sehin
# ...
